# %% [markdown]
# <a href="https://colab.research.google.com/github/Rudratyagi1/nlp_practice/blob/main/BOW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
messages=pd.read_csv('/content/SMSSpamCollection',
                    sep='\t',names=["label","message"])

# %%
messages.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#data cleaning

# %%
df = messages

# %%
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
corpus = []
for i in range(0,len(df)):
  review = re.sub('[^a-zA-Z]',' ',df['message'][i])
  review = review.lower()
  review = review.split()
  review = [lemmatizer.lemmatize(word) for word in review if not word in stopwords.words('english')]
  review = ' '.join(review)
  corpus.append(review)

# %%
##create bags of word model
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=100 , binary = True)
X = cv.fit_transform(corpus).toarray()

# %%
X.shape
# Out:
# (5572, 100)

# %%
cv.vocabulary_
# Out:
# {'go': np.int64(23),
#  'great': np.int64(27),
#  'got': np.int64(26),
#  'wat': np.int64(90),
#  'ok': np.int64(59),
#  'free': np.int64(19),
#  'win': np.int64(94),
#  'text': np.int64(79),
#  'txt': np.int64(86),
#  'say': np.int64(70),
#  'already': np.int64(0),
#  'think': np.int64(82),
#  'life': np.int64(39),
#  'hey': np.int64(30),
#  'week': np.int64(92),
#  'back': np.int64(6),
#  'like': np.int64(40),
#  'still': np.int64(75),
#  'send': np.int64(72),
#  'friend': np.int64(20),
#  'prize': np.int64(65),
#  'claim': np.int64(10),
#  'call': np.int64(7),
#  'mobile': np.int64(50),
#  'co': np.int64(11),
#  'home': np.int64(32),
#  'want': np.int64(89),
#  'today': np.int64(84),
#  'cash': np.int64(9),
#  'day': np.int64(15),
#  'reply': np.int64(67),
#  'www': np.int64(96),
#  'right': np.int64(68),
#  'take': np.int64(77),
#  'time': np.int64(83),
#  'message': np.int64(47),
#  'com': np.int64(12),
#  'oh': np.int64(58),
#  'yes': np.int64(99),
#  'make': np.int64(45),
#  'way': np.int64(91),
#  'dont': np.int64(17),
#  'miss': np.int64(49),
#  'ur': np.int64(88),
#  'going': np.int64(24),
#  'da': np.int64(14),
#  'lor': np.int64(42),
#  'meet': np.int64(46),
#  'really': np.int64(66),
#  'know': np.int64(35),
#  'lol': np.int64(41),
#  'love': np.int64(43),
#  'amp': np.int64(2),
#  'let': np.int64(38),
#  'work': np.int64(95),
#  'yeah': np.int64(97),
#  'tell': np.int64(78),
#  'anything': np.int64(3),
#  'thanks': np.int64(80),
#  'uk': np.int64(87),
#  'please': np.int64(63),
#  'msg': np.int64(52),
#  'see': np.int64(71),
#  'pls': np.int64(64),
#  'need': np.int64(54),
#  'tomorrow': np.int64(85),
#  'hope': np.int64(33),
#  'well': np.int64(93),
#  'lt': np.int64(44),
#  'gt': np.int64(28),
#  'get': np.int64(21),
#  'ask': np.int64(4),
#  'morning': np.int64(51),
#  'happy': np.int64(29),
#  'sorry': np.int64(74),
#  'give': np.int64(22),
#  'new': np.int64(55),
#  'find': np.int64(18),
#  'year': np.int64(98),
#  'later': np.int64(37),
#  'pick': np.int64(62),
#  'good': np.int64(25),
#  'come': np.int64(13),
#  'said': np.int64(69),
#  'hi': np.int64(31),
#  'babe': np.int64(5),
#  'im': np.int64(34),
#  'much': np.int64(53),
#  'stop': np.int64(76),
#  'one': np.int64(60),
#  'night': np.int64(56),
#  'service': np.int64(73),
#  'dear': np.int64(16),
#  'thing': np.int64(81),
#  'last': np.int64(36),
#  'min': np.int64(48),
#  'number': np.int64(57),
#  'also': np.int64(1),
#  'care': np.int64(8),
#  'phone': np.int64(61)}

# %%
##create bags of word model
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=500 , binary = True , ngram_range=(2,2))
X = cv.fit_transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'free entry': np.int64(127),
#  'rate apply': np.int64(338),
#  'per request': np.int64(308),
#  'callertune caller': np.int64(43),
#  'caller press': np.int64(41),
#  'friend callertune': np.int64(131),
#  'claim call': np.int64(56),
#  'call claim': np.int64(24),
#  'claim code': np.int64(57),
#  'entitled update': np.int64(114),
#  'update latest': np.int64(435),
#  'latest colour': np.int64(211),
#  'free call': np.int64(125),
#  'call mobile': np.int64(32),
#  'mobile update': np.int64(263),
#  'chance win': np.int64(55),
#  'win cash': np.int64(481),
#  'reply hl': np.int64(344),
#  'hl info': np.int64(185),
#  'txt word': np.int64(430),
#  'dont miss': np.int64(104),
#  'ha ha': np.int64(173),
#  'let know': np.int64(217),
#  'feel like': np.int64(119),
#  'yeah got': np.int64(497),
#  'tell anything': np.int64(401),
#  'mobile charged': np.int64(259),
#  'go home': np.int64(149),
#  'anything lor': np.int64(4),
#  'want need': np.int64(469),
#  'call reply': np.int64(36),
#  'nokia mobile': np.int64(289),
#  'mobile free': np.int64(260),
#  'free camcorder': np.int64(126),
#  'please call': np.int64(315),
#  'delivery tomorrow': np.int64(98),
#  'lt gt': np.int64(233),
#  'missed call': np.int64(257),
#  'want go': np.int64(467),
#  'first time': np.int64(124),
#  'like lt': np.int64(221),
#  'sm ac': np.int64(375),
#  'bx ip': np.int64(21),
#  'sorry call': np.int64(380),
#  'call later': np.int64(30),
#  'later meeting': np.int64(208),
#  'awarded bonus': np.int64(11),
#  'prize call': np.int64(334),
#  'ur awarded': np.int64(436),
#  'hi babe': np.int64(182),
#  'call free': np.int64(26),
#  'thats cool': np.int64(410),
#  'hi hi': np.int64(184),
#  'wen ur': np.int64(480),
#  'call customer': np.int64(25),
#  'customer service': np.int64(89),
#  'service representative': np.int64(367),
#  'pm guaranteed': np.int64(322),
#  'guaranteed cash': np.int64(168),
#  'cash prize': np.int64(53),
#  'po box': np.int64(324),
#  'need get': np.int64(276),
#  'get home': np.int64(139),
#  'trying contact': np.int64(425),
#  'contact last': np.int64(78),
#  'last weekend': np.int64(207),
#  'weekend draw': np.int64(476),
#  'draw show': np.int64(107),
#  'show prize': np.int64(369),
#  'prize guaranteed': np.int64(336),
#  'guaranteed call': np.int64(167),
#  'valid hr': np.int64(454),
#  'hr ppm': np.int64(192),
#  'said happy': np.int64(354),
#  'happy day': np.int64(177),
#  'special askd': np.int64(385),
#  'lunch lunch': np.int64(237),
#  'specially selected': np.int64(387),
#  'selected receive': np.int64(362),
#  'speak live': np.int64(383),
#  'live operator': np.int64(224),
#  'operator claim': np.int64(303),
#  'private account': np.int64(333),
#  'account statement': np.int64(0),
#  'statement show': np.int64(389),
#  'call identifier': np.int64(27),
#  'identifier code': np.int64(194),
#  'code expires': np.int64(62),
#  'urgent mobile': np.int64(450),
#  'bonus caller': np.int64(17),
#  'caller prize': np.int64(42),
#  'contact call': np.int64(76),
#  'call landline': np.int64(29),
#  'today voda': np.int64(418),
#  'voda number': np.int64(457),
#  'number ending': np.int64(294),
#  'ending selected': np.int64(113),
#  'receive award': np.int64(341),
#  'match please': np.int64(245),
#  'wat time': np.int64(471),
#  'time finish': np.int64(412),
#  'long time': np.int64(226),
#  'give call': np.int64(145),
#  'dear call': np.int64(94),
#  'sony dvd': np.int64(379),
#  'want get': np.int64(466),
#  'ur mob': np.int64(443),
#  'join uk': np.int64(197),
#  'go get': np.int64(148),
#  'sir waiting': np.int64(372),
#  'gud ni': np.int64(171),
#  'yes see': np.int64(499),
#  'per msg': np.int64(307),
#  'reply stop': np.int64(345),
#  'stop end': np.int64(391),
#  'new year': np.int64(284),
#  'miss already': np.int64(256),
#  'new job': np.int64(280),
#  'inviting friend': np.int64(196),
#  'friend reply': np.int64(132),
#  'reply yes': np.int64(346),
#  'see www': np.int64(361),
#  'www sm': np.int64(492),
#  'stop send': np.int64(393),
#  'send stop': np.int64(365),
#  'stop frnd': np.int64(392),
#  'ur mobile': np.int64(444),
#  'urgent trying': np.int64(452),
#  'co uk': np.int64(61),
#  'keep touch': np.int64(198),
#  'gr day': np.int64(160),
#  'gud mrng': np.int64(170),
#  'nice day': np.int64(286),
#  'person story': np.int64(311),
#  'see tomorrow': np.int64(360),
#  'lt decimal': np.int64(232),
#  'decimal gt': np.int64(96),
#  'like dat': np.int64(219),
#  'get ready': np.int64(140),
#  'hope great': np.int64(190),
#  'new mobile': np.int64(281),
#  'txt nokia': np.int64(428),
#  'good morning': np.int64(157),
#  'person dont': np.int64(310),
#  'ur friend': np.int64(438),
#  'secret admirer': np.int64(358),
#  'admirer looking': np.int64(2),
#  'looking make': np.int64(228),
#  'make contact': np.int64(239),
#  'contact find': np.int64(77),
#  'find reveal': np.int64(123),
#  'reveal think': np.int64(347),
#  'think ur': np.int64(411),
#  'ur special': np.int64(447),
#  'special call': np.int64(386),
#  'oh ok': np.int64(297),
#  'good night': np.int64(158),
#  'congratulation ur': np.int64(75),
#  'gift guaranteed': np.int64(143),
#  'draw txt': np.int64(108),
#  'txt music': np.int64(427),
#  'music tncs': np.int64(272),
#  'www ldew': np.int64(491),
#  'ldew com': np.int64(214),
#  'com win': np.int64(68),
#  'win ppmx': np.int64(483),
#  'ppmx age': np.int64(331),
#  'lemme know': np.int64(215),
#  'get back': np.int64(137),
#  'tried contact': np.int64(424),
#  'anytime network': np.int64(5),
#  'network min': np.int64(278),
#  'unlimited text': np.int64(434),
#  'camcorder reply': np.int64(44),
#  'reply call': np.int64(343),
#  'text stop': np.int64(407),
#  'another day': np.int64(3),
#  'last night': np.int64(204),
#  'camera phone': np.int64(47),
#  'cant pick': np.int64(48),
#  'pick phone': np.int64(314),
#  'phone right': np.int64(313),
#  'right pls': np.int64(348),
#  'pls send': np.int64(320),
#  'send message': np.int64(364),
#  'great day': np.int64(161),
#  'mobile mths': np.int64(261),
#  'colour camera': np.int64(65),
#  'camera mobile': np.int64(46),
#  'babe love': np.int64(14),
#  'love ya': np.int64(231),
#  'cool text': np.int64(82),
#  'per minute': np.int64(306),
#  'valentine day': np.int64(453),
#  'send go': np.int64(363),
#  'msg rcvd': np.int64(269),
#  'ur cash': np.int64(437),
#  'cash balance': np.int64(51),
#  'balance currently': np.int64(15),
#  'currently pound': np.int64(88),
#  'pound maximize': np.int64(330),
#  'maximize ur': np.int64(248),
#  'cash send': np.int64(54),
#  'msg cc': np.int64(268),
#  'hg suite': np.int64(181),
#  'suite land': np.int64(395),
#  'land row': np.int64(201),
#  'row hl': np.int64(350),
#  'good afternoon': np.int64(154),
#  'take care': np.int64(397),
#  'latest motorola': np.int64(212),
#  'motorola sonyericsson': np.int64(266),
#  'double min': np.int64(106),
#  'call mobileupd': np.int64(33),
#  'mobileupd call': np.int64(264),
#  'call optout': np.int64(34),
#  'gt min': np.int64(164),
#  'thanks ringtone': np.int64(409),
#  'ringtone order': np.int64(349),
#  'per week': np.int64(309),
#  'min txts': np.int64(255),
#  'half price': np.int64(175),
#  'line rental': np.int64(223),
#  'latest camera': np.int64(210),
#  'phone free': np.int64(312),
#  'call back': np.int64(22),
#  'good evening': np.int64(156),
#  'txt stop': np.int64(429),
#  'fullonsms com': np.int64(134),
#  'yan jiu': np.int64(495),
#  'dating service': np.int64(90),
#  'box sk': np.int64(19),
#  'dont want': np.int64(105),
#  'entry weekly': np.int64(115),
#  'pobox wq': np.int64(327),
#  'last week': np.int64(206),
#  'contacted dating': np.int64(80),
#  'find call': np.int64(121),
#  'mobile number': np.int64(262),
#  'number awarded': np.int64(293),
#  'awarded prize': np.int64(12),
#  'call land': np.int64(28),
#  'land line': np.int64(200),
#  'line claim': np.int64(222),
#  'claim valid': np.int64(60),
#  'ok ok': np.int64(299),
#  'watching tv': np.int64(472),
#  'call call': np.int64(23),
#  'cost ppm': np.int64(84),
#  'call min': np.int64(31),
#  'wc xx': np.int64(473),
#  'gt th': np.int64(166),
#  'gt dollar': np.int64(162),
#  'gt lt': np.int64(163),
#  'well done': np.int64(479),
#  'hope good': np.int64(189),
#  'good day': np.int64(155),
#  'help call': np.int64(179),
#  'free text': np.int64(130),
#  'text back': np.int64(404),
#  'tenerife holiday': np.int64(403),
#  'holiday cash': np.int64(188),
#  'award call': np.int64(10),
#  'sae box': np.int64(351),
#  'cant wait': np.int64(49),
#  'visit www': np.int64(456),
#  'meeting call': np.int64(249),
#  'prize claim': np.int64(335),
#  'pls reply': np.int64(319),
#  'latest nokia': np.int64(213),
#  'gb ipod': np.int64(136),
#  'mp player': np.int64(267),
#  'tone reply': np.int64(421),
#  'tone txt': np.int64(422),
#  'http www': np.int64(193),
#  'prize nd': np.int64(337),
#  'nd attempt': np.int64(274),
#  'attempt contact': np.int64(8),
#  'claim ur': np.int64(59),
#  'ur worth': np.int64(448),
#  'worth discount': np.int64(487),
#  'discount voucher': np.int64(102),
#  'text yes': np.int64(408),
#  'yes savamob': np.int64(498),
#  'savamob member': np.int64(355),
#  'member offer': np.int64(250),
#  'offer mobile': np.int64(295),
#  'show un': np.int64(370),
#  'un redeemed': np.int64(433),
#  'redeemed point': np.int64(342),
#  'point call': np.int64(328),
#  'love go': np.int64(230),
#  'go day': np.int64(147),
#  'kiss across': np.int64(199),
#  'across sea': np.int64(1),
#  'later tonight': np.int64(209),
#  'many many': np.int64(243),
#  'many happy': np.int64(242),
#  'happy birthday': np.int64(176),
#  'yar lor': np.int64(496),
#  'waiting call': np.int64(460),
#  'new video': np.int64(283),
#  'video phone': np.int64(455),
#  'one day': np.int64(301),
#  'shopping spree': np.int64(368),
#  'service announcement': np.int64(366),
#  'sleep well': np.int64(374),
#  'ok lor': np.int64(298),
#  'want come': np.int64(465),
#  'many time': np.int64(244),
#  'make sure': np.int64(240),
#  'dear voucher': np.int64(95),
#  'voucher holder': np.int64(458),
#  'stop text': np.int64(394),
#  'gud evng': np.int64(169),
#  'going home': np.int64(152),
#  'say hi': np.int64(357),
#  'every week': np.int64(116),
#  'come home': np.int64(70),
#  'pls call': np.int64(316),
#  'message waiting': np.int64(251),
#  'look like': np.int64(227),
#  'offer new': np.int64(296),
#  'new nokia': np.int64(282),
#  'good time': np.int64(159),
#  'day send': np.int64(92),
#  'next week': np.int64(285),
#  'happy new': np.int64(178),
#  'every wk': np.int64(117),
#  'wk txt': np.int64(486),
#  'gt minute': np.int64(165),
#  'national rate': np.int64(273),
#  'pobox uz': np.int64(326),
#  'lt time': np.int64(234),
#  'time gt': np.int64(413),
#  'free st': np.int64(129),
#  'st week': np.int64(388),
#  'week nokia': np.int64(474),
#  'nokia tone': np.int64(290),
#  'tone ur': np.int64(423),
#  'week txt': np.int64(475),
#  'nokia get': np.int64(288),
#  'get txting': np.int64(141),
#  'txting tell': np.int64(431),
#  'tell ur': np.int64(402),
#  'ur mate': np.int64(442),
#  'mate www': np.int64(246),
#  'www getzed': np.int64(490),
#  'getzed co': np.int64(142),
#  'uk pobox': np.int64(432),
#  'wq norm': np.int64(489),
#  'norm tone': np.int64(291),
#  'gift voucher': np.int64(144),
#  'weekly draw': np.int64(478),
#  'ok take': np.int64(300),
#  'teasing kiss': np.int64(400),
#  'comuk net': np.int64(73),
#  'net login': np.int64(277),
#  'say hello': np.int64(356),
#  'didnt get': np.int64(100),
#  'morning dear': np.int64(265),
#  'min text': np.int64(254),
#  'landline complimentary': np.int64(202),
#  'cash await': np.int64(50),
#  'await collection': np.int64(9),
#  'collection sae': np.int64(64),
#  'sae po': np.int64(352),
#  'wan go': np.int64(462),
#  'price line': np.int64(332),
#  'dont know': np.int64(103),
#  'text call': np.int64(405),
#  'sk xh': np.int64(373),
#  'light someone': np.int64(218),
#  'contact today': np.int64(79),
#  'today draw': np.int64(417),
#  'come back': np.int64(69),
#  'wait till': np.int64(459),
#  'congrats mobile': np.int64(74),
#  'call videochat': np.int64(40),
#  'game dload': np.int64(135),
#  'music noline': np.int64(271),
#  'call tomorrow': np.int64(39),
#  'wan come': np.int64(461),
#  'mob every': np.int64(258),
#  'mail id': np.int64(238),
#  'gud nyt': np.int64(172),
#  'someone know': np.int64(377),
#  'call sir': np.int64(37),
#  'final attempt': np.int64(120),
#  'txt chat': np.int64(426),
#  'would like': np.int64(488),
#  'awarded sipix': np.int64(13),
#  'sipix digital': np.int64(371),
#  'digital camera': np.int64(101),
#  'camera call': np.int64(45),
#  'landline delivery': np.int64(203),
#  'delivery within': np.int64(99),
#  'within day': np.int64(485),
#  'sorry da': np.int64(381),
#  'important information': np.int64(195),
#  'lucky day': np.int64(236),
#  'day find': np.int64(91),
#  'find log': np.int64(122),
#  'log onto': np.int64(225),
#  'onto http': np.int64(302),
#  'www urawinner': np.int64(493),
#  'urawinner com': np.int64(449),
#  'com fantastic': np.int64(67),
#  'hl ldn': np.int64(186),
#  'take part': np.int64(398),
#  'ur home': np.int64(440),
#  'half hour': np.int64(174),
#  'tone free': np.int64(420),
#  'weekly comp': np.int64(477),
#  'min stop': np.int64(253),
#  'sound like': np.int64(382),
#  'network operator': np.int64(279),
#  'hey babe': np.int64(180),
#  'ur smile': np.int64(446),
#  'something like': np.int64(378),
#  'ur heart': np.int64(439),
#  'fantasy call': np.int64(118),
#  'call per': np.int64(35),
#  'per min': np.int64(305),
#  'min ntt': np.int64(252),
#  'ntt ltd': np.int64(292),
#  'ltd po': np.int64(235),
#  'box croydon': np.int64(18),
#  'croydon cr': np.int64(87),
#  'cr wb': np.int64(86),
#  'sweet dream': np.int64(396),
#  'go back': np.int64(146),
#  'cash every': np.int64(52),
#  'ur sm': np.int64(445),
#  'friendship good': np.int64(133),
#  'wan meet': np.int64(463),
#  'rate call': np.int64(339),
#  'bt national': np.int64(20),
#  'dun haf': np.int64(109),
#  'pls pls': np.int64(318),
#  'go well': np.int64(150),
#  'win free': np.int64(482),
#  'plus free': np.int64(321),
#  'want know': np.int64(468),
#  'wan watch': np.int64(464),
#  'around lt': np.int64(6),
#  'let go': np.int64(216),
#  'ur life': np.int64(441),
#  'coming home': np.int64(72),
#  'free msg': np.int64(128),
#  'dun wan': np.int64(110),
#  'come tomorrow': np.int64(71),
#  'nd time': np.int64(275),
#  'time tried': np.int64(414),
#  'claim easy': np.int64(58),
#  'easy call': np.int64(112),
#  'god love': np.int64(151),
#  'love amp': np.int64(229),
#  'urgent please': np.int64(451),
#  'costa del': np.int64(85),
#  'del sol': np.int64(97),
#  'sol holiday': np.int64(376),
#  'holiday await': np.int64(187),
#  'collection call': np.int64(63),
#  'call toclaim': np.int64(38),
#  'toclaim sae': np.int64(415),
#  'sae tc': np.int64(353),
#  'tc pobox': np.int64(399),
#  'pobox stockport': np.int64(325),
#  'stockport sk': np.int64(390),
#  'xh cost': np.int64(494),
#  'cost pm': np.int64(83),
#  'pm max': np.int64(323),
#  'max min': np.int64(247),
#  'going sleep': np.int64(153),
#  'speak soon': np.int64(384),
#  'hi darlin': np.int64(183),
#  'get free': np.int64(138),
#  'dunno lei': np.int64(111),
#  'pls convey': np.int64(317),
#  'convey birthday': np.int64(81),
#  'birthday wish': np.int64(16),
#  'wish nimya': np.int64(484),
#  'nimya pls': np.int64(287),
#  'today birthday': np.int64(416),
#  'man last': np.int64(241),
#  'day wife': np.int64(93),
#  'sed sexy': np.int64(359),
#  'like hour': np.int64(220),
#  'tone arrive': np.int64(419),
#  'arrive please': np.int64(7),
#  'murdered lt': np.int64(270),
#  'house maid': np.int64(191),
#  'post office': np.int64(329),
#  'last nite': np.int64(205),
#  'orange tariff': np.int64(304),
#  'want new': np.int64(470),
#  'colour phone': np.int64(66),
#  'text free': np.int64(406),
#  'really need': np.int64(340)}
